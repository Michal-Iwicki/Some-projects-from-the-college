# %%
import os
import time

from torchvision import transforms
import torchvision.models as models
import torch.nn as nn
import torch.optim as optim

from loader import load_png_images
from implementation import CNNClassifier, train_model

# %%
def prettify_duration(duration_in_seconds):
    s = duration_in_seconds % 60
    duration_in_seconds -= s
    duration_in_seconds //= 60

    m = duration_in_seconds % 60
    duration_in_seconds -= m
    duration_in_seconds //= 60

    return f"{duration_in_seconds}h {m}m {s}s"

# %%
PREFIX = "sample"

# %%
train_path = os.path.join(os.getcwd(), "data", PREFIX, "train")
valid_path = os.path.join(os.getcwd(), "data", PREFIX, "valid")
test_path = os.path.join(os.getcwd(), "data", PREFIX, "test")

# %%
transformations = {
    
}

# %%
for transformation_name, transformation in transformations.items():
    print("==============================================================================")
    print(f"transformation: {transformation_name}")
    print("------------------------------------------------------------------------------")
    
    train, t_n = load_png_images(train_path, transform=transformation, batch_size=64)
    valid, v_n = load_png_images(valid_path, transform=transformation, batch_size=2048)

    m_models = {
        "custom-cnn": CNNClassifier(t_n),
        "densnet": models.densenet121(weights="DenseNet121_Weights.IMAGENET1K_V1"),
        "wide-resnet": models.wide_resnet50_2(weights="Wide_ResNet50_2_Weights.DEFAULT")
    }
    m_models["densnet"].classifier = nn.Linear(m_models["densnet"].classifier.in_features, t_n)
    m_models["wide-resnet"].fc = nn.Linear(m_models["wide-resnet"].fc.in_features, t_n)
    
    for model_name, model in m_models.items():
        print(f"model: {model_name}")
        print()
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        
        start = time.time()
        train_model(model, train, valid, criterion, optimizer, epochs=10)
        end = time.time()

        print(f"training took {prettify_duration(end - start)}")
        print()
# Out:
# ==============================================================================
# transformation: no-transform
# ------------------------------------------------------------------------------
# model: custom-cnn
#
# Epoch 1/10, Loss: 0.6950, Validation Accuracy: 57.60%
# Epoch 2/10, Loss: 0.6724, Validation Accuracy: 63.00%
# Epoch 3/10, Loss: 0.6240, Validation Accuracy: 66.40%
# Epoch 4/10, Loss: 0.5965, Validation Accuracy: 67.20%
# Epoch 5/10, Loss: 0.5664, Validation Accuracy: 68.00%
# Epoch 6/10, Loss: 0.5296, Validation Accuracy: 69.80%
# Epoch 7/10, Loss: 0.5240, Validation Accuracy: 67.60%
# Epoch 8/10, Loss: 0.5225, Validation Accuracy: 73.00%
# Epoch 9/10, Loss: 0.4393, Validation Accuracy: 73.40%
# Epoch 10/10, Loss: 0.3915, Validation Accuracy: 74.20%
# training took 0.0h 1.0m 10.306885242462158s
#
# model: densnet
#
# Epoch 1/10, Loss: 0.6440, Validation Accuracy: 70.80%
# Epoch 2/10, Loss: 0.3695, Validation Accuracy: 73.20%
# Epoch 3/10, Loss: 0.2403, Validation Accuracy: 78.80%
# Epoch 4/10, Loss: 0.0825, Validation Accuracy: 75.40%
# Epoch 5/10, Loss: 0.0715, Validation Accuracy: 77.20%
# Epoch 6/10, Loss: 0.0407, Validation Accuracy: 77.60%
# Epoch 7/10, Loss: 0.0548, Validation Accuracy: 73.40%
# Epoch 8/10, Loss: 0.0495, Validation Accuracy: 77.80%
# Epoch 9/10, Loss: 0.1894, Validation Accuracy: 71.40%
# Epoch 10/10, Loss: 0.1244, Validation Accuracy: 70.40%
# training took 0.0h 2.0m 29.079166889190674s
#
# model: wide-resnet
#
# Epoch 1/10, Loss: 0.6487, Validation Accuracy: 77.00%
# Epoch 2/10, Loss: 0.3143, Validation Accuracy: 79.80%
# Epoch 3/10, Loss: 0.1263, Validation Accuracy: 77.60%
# Epoch 4/10, Loss: 0.0738, Validation Accuracy: 76.20%
# Epoch 5/10, Loss: 0.0523, Validation Accuracy: 77.20%
# Epoch 6/10, Loss: 0.0242, Validation Accuracy: 75.80%
# Epoch 7/10, Loss: 0.0357, Validation Accuracy: 75.40%
# Epoch 8/10, Loss: 0.0380, Validation Accuracy: 76.20%
# Epoch 9/10, Loss: 0.1183, Validation Accuracy: 76.60%
# Epoch 10/10, Loss: 0.1240, Validation Accuracy: 75.80%
# training took 0.0h 9.0m 5.268021583557129s
#
# ==============================================================================
# transformation: flips
# ------------------------------------------------------------------------------
# model: custom-cnn
#
# Epoch 1/10, Loss: 0.6994, Validation Accuracy: 58.60%
# Epoch 2/10, Loss: 0.6796, Validation Accuracy: 60.20%
# Epoch 3/10, Loss: 0.6490, Validation Accuracy: 66.00%
# Epoch 4/10, Loss: 0.6234, Validation Accuracy: 68.20%
# Epoch 5/10, Loss: 0.6111, Validation Accuracy: 68.80%
# Epoch 6/10, Loss: 0.6009, Validation Accuracy: 62.80%
# Epoch 7/10, Loss: 0.6024, Validation Accuracy: 71.60%
# Epoch 8/10, Loss: 0.5863, Validation Accuracy: 69.40%
# Epoch 9/10, Loss: 0.5886, Validation Accuracy: 71.80%
# Epoch 10/10, Loss: 0.5623, Validation Accuracy: 70.20%
# training took 0.0h 0.0m 36.606157541275024s
#
# model: densnet
#
# Epoch 1/10, Loss: 0.6325, Validation Accuracy: 69.60%
# Epoch 2/10, Loss: 0.4898, Validation Accuracy: 73.40%
# Epoch 3/10, Loss: 0.4835, Validation Accuracy: 68.20%
# Epoch 4/10, Loss: 0.3695, Validation Accuracy: 71.20%
# Epoch 5/10, Loss: 0.3200, Validation Accuracy: 76.80%
# Epoch 6/10, Loss: 0.2581, Validation Accuracy: 73.80%
# Epoch 7/10, Loss: 0.2024, Validation Accuracy: 71.40%
# Epoch 8/10, Loss: 0.2068, Validation Accuracy: 74.00%
# Epoch 9/10, Loss: 0.2280, Validation Accuracy: 73.00%
# Epoch 10/10, Loss: 0.2527, Validation Accuracy: 76.40%
# training took 0.0h 2.0m 48.63541769981384s
#
# model: wide-resnet
#
# Epoch 1/10, Loss: 0.6585, Validation Accuracy: 73.00%
# Epoch 2/10, Loss: 0.4807, Validation Accuracy: 75.80%
# Epoch 3/10, Loss: 0.3554, Validation Accuracy: 75.40%
# Epoch 4/10, Loss: 0.3305, Validation Accuracy: 74.80%
# Epoch 5/10, Loss: 0.2906, Validation Accuracy: 78.60%
# Epoch 6/10, Loss: 0.2472, Validation Accuracy: 79.40%
# Epoch 7/10, Loss: 0.2195, Validation Accuracy: 76.60%
# Epoch 8/10, Loss: 0.1790, Validation Accuracy: 78.20%
# Epoch 9/10, Loss: 0.1448, Validation Accuracy: 76.40%
# Epoch 10/10, Loss: 0.1233, Validation Accuracy: 74.00%
# training took 0.0h 9.0m 22.530717611312866s
#
# ==============================================================================
# transformation: auto-augment
# ------------------------------------------------------------------------------
# model: custom-cnn
#
# Epoch 1/10, Loss: 0.6986, Validation Accuracy: 52.00%
# Epoch 2/10, Loss: 0.6941, Validation Accuracy: 50.00%
# Epoch 3/10, Loss: 0.6921, Validation Accuracy: 56.00%
# Epoch 4/10, Loss: 0.6872, Validation Accuracy: 56.80%
# Epoch 5/10, Loss: 0.6850, Validation Accuracy: 60.60%
# Epoch 6/10, Loss: 0.6765, Validation Accuracy: 62.40%
# Epoch 7/10, Loss: 0.6702, Validation Accuracy: 52.00%
# Epoch 8/10, Loss: 0.6724, Validation Accuracy: 64.00%
# Epoch 9/10, Loss: 0.6529, Validation Accuracy: 64.20%
# Epoch 10/10, Loss: 0.6389, Validation Accuracy: 67.40%
# training took 0.0h 0.0m 49.77617573738098s
#
# model: densnet
#
# Epoch 1/10, Loss: 0.6709, Validation Accuracy: 65.80%
# Epoch 2/10, Loss: 0.6022, Validation Accuracy: 69.60%
# Epoch 3/10, Loss: 0.5483, Validation Accuracy: 69.00%
# Epoch 4/10, Loss: 0.5093, Validation Accuracy: 73.40%
# Epoch 5/10, Loss: 0.5223, Validation Accuracy: 75.40%
# Epoch 6/10, Loss: 0.4415, Validation Accuracy: 75.80%
# Epoch 7/10, Loss: 0.4167, Validation Accuracy: 74.60%
# Epoch 8/10, Loss: 0.3812, Validation Accuracy: 68.40%
# Epoch 9/10, Loss: 0.3302, Validation Accuracy: 73.80%
# Epoch 10/10, Loss: 0.3426, Validation Accuracy: 72.60%
# training took 0.0h 3.0m 1.9655392169952393s
#
# model: wide-resnet
#
# Epoch 1/10, Loss: 0.6956, Validation Accuracy: 66.20%
# Epoch 2/10, Loss: 0.5485, Validation Accuracy: 71.00%
# Epoch 3/10, Loss: 0.4712, Validation Accuracy: 71.80%
# Epoch 4/10, Loss: 0.4437, Validation Accuracy: 74.20%
# Epoch 5/10, Loss: 0.4421, Validation Accuracy: 71.00%
# Epoch 6/10, Loss: 0.4186, Validation Accuracy: 72.20%
# Epoch 7/10, Loss: 0.3751, Validation Accuracy: 72.60%
# Epoch 8/10, Loss: 0.3667, Validation Accuracy: 73.60%
# Epoch 9/10, Loss: 0.3274, Validation Accuracy: 75.80%
# Epoch 10/10, Loss: 0.3156, Validation Accuracy: 72.60%
# training took 0.0h 9.0m 44.35548138618469s
#
# ==============================================================================
# transformation: rand-augment
# ------------------------------------------------------------------------------
# model: custom-cnn
#
# Epoch 1/10, Loss: 0.7015, Validation Accuracy: 50.00%
# Epoch 2/10, Loss: 0.6932, Validation Accuracy: 52.00%
# Epoch 3/10, Loss: 0.6890, Validation Accuracy: 61.20%
# Epoch 4/10, Loss: 0.6745, Validation Accuracy: 62.00%
# Epoch 5/10, Loss: 0.6468, Validation Accuracy: 64.40%
# Epoch 6/10, Loss: 0.6450, Validation Accuracy: 66.20%
# Epoch 7/10, Loss: 0.6470, Validation Accuracy: 62.60%
# Epoch 8/10, Loss: 0.6505, Validation Accuracy: 61.20%
# Epoch 9/10, Loss: 0.6334, Validation Accuracy: 66.60%
# Epoch 10/10, Loss: 0.6232, Validation Accuracy: 65.80%
# training took 0.0h 0.0m 49.700483560562134s
#
# model: densnet
#
# Epoch 1/10, Loss: 0.6803, Validation Accuracy: 64.00%
# Epoch 2/10, Loss: 0.6400, Validation Accuracy: 71.60%
# Epoch 3/10, Loss: 0.5210, Validation Accuracy: 72.20%
# Epoch 4/10, Loss: 0.4977, Validation Accuracy: 70.00%
# Epoch 5/10, Loss: 0.4643, Validation Accuracy: 74.20%
# Epoch 6/10, Loss: 0.4451, Validation Accuracy: 76.20%
# Epoch 7/10, Loss: 0.4439, Validation Accuracy: 76.00%
# Epoch 8/10, Loss: 0.4090, Validation Accuracy: 71.40%
# Epoch 9/10, Loss: 0.3775, Validation Accuracy: 73.80%
# Epoch 10/10, Loss: 0.3997, Validation Accuracy: 74.60%
# training took 0.0h 3.0m 1.5045409202575684s
#
# model: wide-resnet
#
# Epoch 1/10, Loss: 0.6584, Validation Accuracy: 69.20%
# Epoch 2/10, Loss: 0.5866, Validation Accuracy: 73.80%
# Epoch 3/10, Loss: 0.5152, Validation Accuracy: 68.00%
# Epoch 4/10, Loss: 0.4535, Validation Accuracy: 75.00%
# Epoch 5/10, Loss: 0.4967, Validation Accuracy: 73.20%
# Epoch 6/10, Loss: 0.4414, Validation Accuracy: 72.80%
# Epoch 7/10, Loss: 0.3996, Validation Accuracy: 70.60%
# Epoch 8/10, Loss: 0.4207, Validation Accuracy: 72.80%
# Epoch 9/10, Loss: 0.3850, Validation Accuracy: 76.00%
# Epoch 10/10, Loss: 0.3380, Validation Accuracy: 76.20%
# training took 0.0h 9.0m 40.83471369743347s
