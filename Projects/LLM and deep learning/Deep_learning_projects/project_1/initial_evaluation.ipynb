# %%
from implementation import CNNClassifier, train_model
from loader import load_png_images
from torchinfo import summary
from torchvision import models
import torch.optim as optim
import torch.nn as nn

train_loader, num_classes = load_png_images("data/train", batch_size=64)  
val_loader,n = load_png_images("data/valid", batch_size=1024, shuffle=False)  
model = CNNClassifier(num_classes)
optimizer = optim.Adam(model.parameters(), lr=0.001)
print(summary(model, input_size=(1, 3, 32, 32)))
train_model(model, train_loader, val_loader, optimizer, epochs=10)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CNNClassifier                            [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 64, 32, 32]           1,792
# ├─BatchNorm2d: 1-2                       [1, 64, 32, 32]           128
# ├─MaxPool2d: 1-3                         [1, 64, 16, 16]           --
# ├─Conv2d: 1-4                            [1, 128, 16, 16]          73,856
# ├─BatchNorm2d: 1-5                       [1, 128, 16, 16]          256
# ├─MaxPool2d: 1-6                         [1, 128, 8, 8]            --
# ├─Conv2d: 1-7                            [1, 256, 8, 8]            295,168
# ├─BatchNorm2d: 1-8                       [1, 256, 8, 8]            512
# ├─MaxPool2d: 1-9                         [1, 256, 4, 4]            --
# ├─Dropout: 1-10                          [1, 4096]                 --
# ├─Linear: 1-11                           [1, 128]                  524,416
# ├─Dropout: 1-12                          [1, 128]                  --
# ├─Linear: 1-13                           [1, 10]                   1,290
# ==========================================================================================
# Total params: 897,418
# Trainable params: 897,418
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 40.16
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.84
# Params size (MB): 3.59
# Estimated Total Size (MB): 5.44
# ==========================================================================================
# Epoch 1/10, Loss: 1.5015, Validation Loss: 1.2628, Validation Accuracy: 53.91%
# Epoch 2/10, Loss: 1.2567, Validation Loss: 1.1228, Validation Accuracy: 59.67%
# Epoch 3/10, Loss: 1.1508, Validation Loss: 1.0710, Validation Accuracy: 61.30%
# Epoch 4/10, Loss: 1.0725, Validation Loss: 1.0273, Validation Accuracy: 62.70%
# Epoch 5/10, Loss: 1.0072, Validation Loss: 0.9558, Validation Accuracy: 65.98%
# Epoch 6/10, Loss: 0.9502, Validation Loss: 0.9315, Validation Accuracy: 66.66%
# Epoch 7/10, Loss: 0.8984, Validation Loss: 0.9167, Validation Accuracy: 67.55%
# Epoch 8/10, Loss: 0.8470, Validation Loss: 0.8702, Validation Accuracy: 69.12%
# Epoch 9/10, Loss: 0.8017, Validation Loss: 0.8809, Validation Accuracy: 69.16%
# Epoch 10/10, Loss: 0.7529, Validation Loss: 0.9015, Validation Accuracy: 69.15%

# %%
model =  models.densenet121(weights="DenseNet121_Weights.IMAGENET1K_V1")
model.classifier = nn.Linear(model.classifier.in_features, num_classes)  
optimizer = optim.Adam(model.parameters())
print(summary(model, input_size=(1, 3, 32, 32)))

train_model(model, train_loader, val_loader, optimizer, epochs=10)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# DenseNet                                 [1, 10]                   --
# ├─Sequential: 1-1                        [1, 1024, 1, 1]           --
# │    └─Conv2d: 2-1                       [1, 64, 16, 16]           9,408
# │    └─BatchNorm2d: 2-2                  [1, 64, 16, 16]           128
# │    └─ReLU: 2-3                         [1, 64, 16, 16]           --
# │    └─MaxPool2d: 2-4                    [1, 64, 8, 8]             --
# │    └─_DenseBlock: 2-5                  [1, 256, 8, 8]            --
# │    │    └─_DenseLayer: 3-1             [1, 32, 8, 8]             45,440
# │    │    └─_DenseLayer: 3-2             [1, 32, 8, 8]             49,600
# │    │    └─_DenseLayer: 3-3             [1, 32, 8, 8]             53,760
# │    │    └─_DenseLayer: 3-4             [1, 32, 8, 8]             57,920
# │    │    └─_DenseLayer: 3-5             [1, 32, 8, 8]             62,080
# │    │    └─_DenseLayer: 3-6             [1, 32, 8, 8]             66,240
# │    └─_Transition: 2-6                  [1, 128, 4, 4]            --
# │    │    └─BatchNorm2d: 3-7             [1, 256, 8, 8]            512
# │    │    └─ReLU: 3-8                    [1, 256, 8, 8]            --
# │    │    └─Conv2d: 3-9                  [1, 128, 8, 8]            32,768
# │    │    └─AvgPool2d: 3-10              [1, 128, 4, 4]            --
# │    └─_DenseBlock: 2-7                  [1, 512, 4, 4]            --
# │    │    └─_DenseLayer: 3-11            [1, 32, 4, 4]             53,760
# │    │    └─_DenseLayer: 3-12            [1, 32, 4, 4]             57,920
# │    │    └─_DenseLayer: 3-13            [1, 32, 4, 4]             62,080
# │    │    └─_DenseLayer: 3-14            [1, 32, 4, 4]             66,240
# │    │    └─_DenseLayer: 3-15            [1, 32, 4, 4]             70,400
# │    │    └─_DenseLayer: 3-16            [1, 32, 4, 4]             74,560
# │    │    └─_DenseLayer: 3-17            [1, 32, 4, 4]             78,720
# │    │    └─_DenseLayer: 3-18            [1, 32, 4, 4]             82,880
# │    │    └─_DenseLayer: 3-19            [1, 32, 4, 4]             87,040
# │    │    └─_DenseLayer: 3-20            [1, 32, 4, 4]             91,200
# │    │    └─_DenseLayer: 3-21            [1, 32, 4, 4]             95,360
# │    │    └─_DenseLayer: 3-22            [1, 32, 4, 4]             99,520
# │    └─_Transition: 2-8                  [1, 256, 2, 2]            --
# │    │    └─BatchNorm2d: 3-23            [1, 512, 4, 4]            1,024
# │    │    └─ReLU: 3-24                   [1, 512, 4, 4]            --
# │    │    └─Conv2d: 3-25                 [1, 256, 4, 4]            131,072
# │    │    └─AvgPool2d: 3-26              [1, 256, 2, 2]            --
# │    └─_DenseBlock: 2-9                  [1, 1024, 2, 2]           --
# │    │    └─_DenseLayer: 3-27            [1, 32, 2, 2]             70,400
# │    │    └─_DenseLayer: 3-28            [1, 32, 2, 2]             74,560
# │    │    └─_DenseLayer: 3-29            [1, 32, 2, 2]             78,720
# │    │    └─_DenseLayer: 3-30            [1, 32, 2, 2]             82,880
# │    │    └─_DenseLayer: 3-31            [1, 32, 2, 2]             87,040
# │    │    └─_DenseLayer: 3-32            [1, 32, 2, 2]             91,200
# │    │    └─_DenseLayer: 3-33            [1, 32, 2, 2]             95,360
# │    │    └─_DenseLayer: 3-34            [1, 32, 2, 2]             99,520
# │    │    └─_DenseLayer: 3-35            [1, 32, 2, 2]             103,680
# │    │    └─_DenseLayer: 3-36            [1, 32, 2, 2]             107,840
# │    │    └─_DenseLayer: 3-37            [1, 32, 2, 2]             112,000
# │    │    └─_DenseLayer: 3-38            [1, 32, 2, 2]             116,160
# │    │    └─_DenseLayer: 3-39            [1, 32, 2, 2]             120,320
# │    │    └─_DenseLayer: 3-40            [1, 32, 2, 2]             124,480
# │    │    └─_DenseLayer: 3-41            [1, 32, 2, 2]             128,640
# │    │    └─_DenseLayer: 3-42            [1, 32, 2, 2]             132,800
# │    │    └─_DenseLayer: 3-43            [1, 32, 2, 2]             136,960
# │    │    └─_DenseLayer: 3-44            [1, 32, 2, 2]             141,120
# │    │    └─_DenseLayer: 3-45            [1, 32, 2, 2]             145,280
# │    │    └─_DenseLayer: 3-46            [1, 32, 2, 2]             149,440
# │    │    └─_DenseLayer: 3-47            [1, 32, 2, 2]             153,600
# │    │    └─_DenseLayer: 3-48            [1, 32, 2, 2]             157,760
# │    │    └─_DenseLayer: 3-49            [1, 32, 2, 2]             161,920
# │    │    └─_DenseLayer: 3-50            [1, 32, 2, 2]             166,080
# │    └─_Transition: 2-10                 [1, 512, 1, 1]            --
# │    │    └─BatchNorm2d: 3-51            [1, 1024, 2, 2]           2,048
# │    │    └─ReLU: 3-52                   [1, 1024, 2, 2]           --
# │    │    └─Conv2d: 3-53                 [1, 512, 2, 2]            524,288
# │    │    └─AvgPool2d: 3-54              [1, 512, 1, 1]            --
# │    └─_DenseBlock: 2-11                 [1, 1024, 1, 1]           --
# │    │    └─_DenseLayer: 3-55            [1, 32, 1, 1]             103,680
# │    │    └─_DenseLayer: 3-56            [1, 32, 1, 1]             107,840
# │    │    └─_DenseLayer: 3-57            [1, 32, 1, 1]             112,000
# │    │    └─_DenseLayer: 3-58            [1, 32, 1, 1]             116,160
# │    │    └─_DenseLayer: 3-59            [1, 32, 1, 1]             120,320
# │    │    └─_DenseLayer: 3-60            [1, 32, 1, 1]             124,480
# │    │    └─_DenseLayer: 3-61            [1, 32, 1, 1]             128,640
# │    │    └─_DenseLayer: 3-62            [1, 32, 1, 1]             132,800
# │    │    └─_DenseLayer: 3-63            [1, 32, 1, 1]             136,960
# │    │    └─_DenseLayer: 3-64            [1, 32, 1, 1]             141,120
# │    │    └─_DenseLayer: 3-65            [1, 32, 1, 1]             145,280
# │    │    └─_DenseLayer: 3-66            [1, 32, 1, 1]             149,440
# │    │    └─_DenseLayer: 3-67            [1, 32, 1, 1]             153,600
# │    │    └─_DenseLayer: 3-68            [1, 32, 1, 1]             157,760
# │    │    └─_DenseLayer: 3-69            [1, 32, 1, 1]             161,920
# │    │    └─_DenseLayer: 3-70            [1, 32, 1, 1]             166,080
# │    └─BatchNorm2d: 2-12                 [1, 1024, 1, 1]           2,048
# ├─Linear: 1-2                            [1, 10]                   10,250
# ==========================================================================================
# Total params: 6,964,106
# Trainable params: 6,964,106
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 57.91
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.68
# Params size (MB): 27.86
# Estimated Total Size (MB): 31.55
# ==========================================================================================
# Epoch 1/10, Loss: 1.3103, Validation Loss: 1.4097, Validation Accuracy: 52.92%

# %%
model = models.wide_resnet50_2(weights="Wide_ResNet50_2_Weights.DEFAULT")
model.fc = nn.Linear(model.fc.in_features, num_classes)
optimizer = optim.Adam(model.parameters(), lr=0.001)
print(summary(model, input_size=(1, 3, 32, 32)))

train_model(model, train_loader, val_loader,  optimizer, epochs=10)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNet                                   [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 64, 16, 16]           9,408
# ├─BatchNorm2d: 1-2                       [1, 64, 16, 16]           128
# ├─ReLU: 1-3                              [1, 64, 16, 16]           --
# ├─MaxPool2d: 1-4                         [1, 64, 8, 8]             --
# ├─Sequential: 1-5                        [1, 256, 8, 8]            --
# │    └─Bottleneck: 2-1                   [1, 256, 8, 8]            --
# │    │    └─Conv2d: 3-1                  [1, 128, 8, 8]            8,192
# │    │    └─BatchNorm2d: 3-2             [1, 128, 8, 8]            256
# │    │    └─ReLU: 3-3                    [1, 128, 8, 8]            --
# │    │    └─Conv2d: 3-4                  [1, 128, 8, 8]            147,456
# │    │    └─BatchNorm2d: 3-5             [1, 128, 8, 8]            256
# │    │    └─ReLU: 3-6                    [1, 128, 8, 8]            --
# │    │    └─Conv2d: 3-7                  [1, 256, 8, 8]            32,768
# │    │    └─BatchNorm2d: 3-8             [1, 256, 8, 8]            512
# │    │    └─Sequential: 3-9              [1, 256, 8, 8]            16,896
# │    │    └─ReLU: 3-10                   [1, 256, 8, 8]            --
# │    └─Bottleneck: 2-2                   [1, 256, 8, 8]            --
# │    │    └─Conv2d: 3-11                 [1, 128, 8, 8]            32,768
# │    │    └─BatchNorm2d: 3-12            [1, 128, 8, 8]            256
# │    │    └─ReLU: 3-13                   [1, 128, 8, 8]            --
# │    │    └─Conv2d: 3-14                 [1, 128, 8, 8]            147,456
# │    │    └─BatchNorm2d: 3-15            [1, 128, 8, 8]            256
# │    │    └─ReLU: 3-16                   [1, 128, 8, 8]            --
# │    │    └─Conv2d: 3-17                 [1, 256, 8, 8]            32,768
# │    │    └─BatchNorm2d: 3-18            [1, 256, 8, 8]            512
# │    │    └─ReLU: 3-19                   [1, 256, 8, 8]            --
# │    └─Bottleneck: 2-3                   [1, 256, 8, 8]            --
# │    │    └─Conv2d: 3-20                 [1, 128, 8, 8]            32,768
# │    │    └─BatchNorm2d: 3-21            [1, 128, 8, 8]            256
# │    │    └─ReLU: 3-22                   [1, 128, 8, 8]            --
# │    │    └─Conv2d: 3-23                 [1, 128, 8, 8]            147,456
# │    │    └─BatchNorm2d: 3-24            [1, 128, 8, 8]            256
# │    │    └─ReLU: 3-25                   [1, 128, 8, 8]            --
# │    │    └─Conv2d: 3-26                 [1, 256, 8, 8]            32,768
# │    │    └─BatchNorm2d: 3-27            [1, 256, 8, 8]            512
# │    │    └─ReLU: 3-28                   [1, 256, 8, 8]            --
# ├─Sequential: 1-6                        [1, 512, 4, 4]            --
# │    └─Bottleneck: 2-4                   [1, 512, 4, 4]            --
# │    │    └─Conv2d: 3-29                 [1, 256, 8, 8]            65,536
# │    │    └─BatchNorm2d: 3-30            [1, 256, 8, 8]            512
# │    │    └─ReLU: 3-31                   [1, 256, 8, 8]            --
# │    │    └─Conv2d: 3-32                 [1, 256, 4, 4]            589,824
# │    │    └─BatchNorm2d: 3-33            [1, 256, 4, 4]            512
# │    │    └─ReLU: 3-34                   [1, 256, 4, 4]            --
# │    │    └─Conv2d: 3-35                 [1, 512, 4, 4]            131,072
# │    │    └─BatchNorm2d: 3-36            [1, 512, 4, 4]            1,024
# │    │    └─Sequential: 3-37             [1, 512, 4, 4]            132,096
# │    │    └─ReLU: 3-38                   [1, 512, 4, 4]            --
# │    └─Bottleneck: 2-5                   [1, 512, 4, 4]            --
# │    │    └─Conv2d: 3-39                 [1, 256, 4, 4]            131,072
# │    │    └─BatchNorm2d: 3-40            [1, 256, 4, 4]            512
# │    │    └─ReLU: 3-41                   [1, 256, 4, 4]            --
# │    │    └─Conv2d: 3-42                 [1, 256, 4, 4]            589,824
# │    │    └─BatchNorm2d: 3-43            [1, 256, 4, 4]            512
# │    │    └─ReLU: 3-44                   [1, 256, 4, 4]            --
# │    │    └─Conv2d: 3-45                 [1, 512, 4, 4]            131,072
# │    │    └─BatchNorm2d: 3-46            [1, 512, 4, 4]            1,024
# │    │    └─ReLU: 3-47                   [1, 512, 4, 4]            --
# │    └─Bottleneck: 2-6                   [1, 512, 4, 4]            --
# │    │    └─Conv2d: 3-48                 [1, 256, 4, 4]            131,072
# │    │    └─BatchNorm2d: 3-49            [1, 256, 4, 4]            512
# │    │    └─ReLU: 3-50                   [1, 256, 4, 4]            --
# │    │    └─Conv2d: 3-51                 [1, 256, 4, 4]            589,824
# │    │    └─BatchNorm2d: 3-52            [1, 256, 4, 4]            512
# │    │    └─ReLU: 3-53                   [1, 256, 4, 4]            --
# │    │    └─Conv2d: 3-54                 [1, 512, 4, 4]            131,072
# │    │    └─BatchNorm2d: 3-55            [1, 512, 4, 4]            1,024
# │    │    └─ReLU: 3-56                   [1, 512, 4, 4]            --
# │    └─Bottleneck: 2-7                   [1, 512, 4, 4]            --
# │    │    └─Conv2d: 3-57                 [1, 256, 4, 4]            131,072
# │    │    └─BatchNorm2d: 3-58            [1, 256, 4, 4]            512
# │    │    └─ReLU: 3-59                   [1, 256, 4, 4]            --
# │    │    └─Conv2d: 3-60                 [1, 256, 4, 4]            589,824
# │    │    └─BatchNorm2d: 3-61            [1, 256, 4, 4]            512
# │    │    └─ReLU: 3-62                   [1, 256, 4, 4]            --
# │    │    └─Conv2d: 3-63                 [1, 512, 4, 4]            131,072
# │    │    └─BatchNorm2d: 3-64            [1, 512, 4, 4]            1,024
# │    │    └─ReLU: 3-65                   [1, 512, 4, 4]            --
# ├─Sequential: 1-7                        [1, 1024, 2, 2]           --
# │    └─Bottleneck: 2-8                   [1, 1024, 2, 2]           --
# │    │    └─Conv2d: 3-66                 [1, 512, 4, 4]            262,144
# │    │    └─BatchNorm2d: 3-67            [1, 512, 4, 4]            1,024
# │    │    └─ReLU: 3-68                   [1, 512, 4, 4]            --
# │    │    └─Conv2d: 3-69                 [1, 512, 2, 2]            2,359,296
# │    │    └─BatchNorm2d: 3-70            [1, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-71                   [1, 512, 2, 2]            --
# │    │    └─Conv2d: 3-72                 [1, 1024, 2, 2]           524,288
# │    │    └─BatchNorm2d: 3-73            [1, 1024, 2, 2]           2,048
# │    │    └─Sequential: 3-74             [1, 1024, 2, 2]           526,336
# │    │    └─ReLU: 3-75                   [1, 1024, 2, 2]           --
# │    └─Bottleneck: 2-9                   [1, 1024, 2, 2]           --
# │    │    └─Conv2d: 3-76                 [1, 512, 2, 2]            524,288
# │    │    └─BatchNorm2d: 3-77            [1, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-78                   [1, 512, 2, 2]            --
# │    │    └─Conv2d: 3-79                 [1, 512, 2, 2]            2,359,296
# │    │    └─BatchNorm2d: 3-80            [1, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-81                   [1, 512, 2, 2]            --
# │    │    └─Conv2d: 3-82                 [1, 1024, 2, 2]           524,288
# │    │    └─BatchNorm2d: 3-83            [1, 1024, 2, 2]           2,048
# │    │    └─ReLU: 3-84                   [1, 1024, 2, 2]           --
# │    └─Bottleneck: 2-10                  [1, 1024, 2, 2]           --
# │    │    └─Conv2d: 3-85                 [1, 512, 2, 2]            524,288
# │    │    └─BatchNorm2d: 3-86            [1, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-87                   [1, 512, 2, 2]            --
# │    │    └─Conv2d: 3-88                 [1, 512, 2, 2]            2,359,296
# │    │    └─BatchNorm2d: 3-89            [1, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-90                   [1, 512, 2, 2]            --
# │    │    └─Conv2d: 3-91                 [1, 1024, 2, 2]           524,288
# │    │    └─BatchNorm2d: 3-92            [1, 1024, 2, 2]           2,048
# │    │    └─ReLU: 3-93                   [1, 1024, 2, 2]           --
# │    └─Bottleneck: 2-11                  [1, 1024, 2, 2]           --
# │    │    └─Conv2d: 3-94                 [1, 512, 2, 2]            524,288
# │    │    └─BatchNorm2d: 3-95            [1, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-96                   [1, 512, 2, 2]            --
# │    │    └─Conv2d: 3-97                 [1, 512, 2, 2]            2,359,296
# │    │    └─BatchNorm2d: 3-98            [1, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-99                   [1, 512, 2, 2]            --
# │    │    └─Conv2d: 3-100                [1, 1024, 2, 2]           524,288
# │    │    └─BatchNorm2d: 3-101           [1, 1024, 2, 2]           2,048
# │    │    └─ReLU: 3-102                  [1, 1024, 2, 2]           --
# │    └─Bottleneck: 2-12                  [1, 1024, 2, 2]           --
# │    │    └─Conv2d: 3-103                [1, 512, 2, 2]            524,288
# │    │    └─BatchNorm2d: 3-104           [1, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-105                  [1, 512, 2, 2]            --
# │    │    └─Conv2d: 3-106                [1, 512, 2, 2]            2,359,296
# │    │    └─BatchNorm2d: 3-107           [1, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-108                  [1, 512, 2, 2]            --
# │    │    └─Conv2d: 3-109                [1, 1024, 2, 2]           524,288
# │    │    └─BatchNorm2d: 3-110           [1, 1024, 2, 2]           2,048
# │    │    └─ReLU: 3-111                  [1, 1024, 2, 2]           --
# │    └─Bottleneck: 2-13                  [1, 1024, 2, 2]           --
# │    │    └─Conv2d: 3-112                [1, 512, 2, 2]            524,288
# │    │    └─BatchNorm2d: 3-113           [1, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-114                  [1, 512, 2, 2]            --
# │    │    └─Conv2d: 3-115                [1, 512, 2, 2]            2,359,296
# │    │    └─BatchNorm2d: 3-116           [1, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-117                  [1, 512, 2, 2]            --
# │    │    └─Conv2d: 3-118                [1, 1024, 2, 2]           524,288
# │    │    └─BatchNorm2d: 3-119           [1, 1024, 2, 2]           2,048
# │    │    └─ReLU: 3-120                  [1, 1024, 2, 2]           --
# ├─Sequential: 1-8                        [1, 2048, 1, 1]           --
# │    └─Bottleneck: 2-14                  [1, 2048, 1, 1]           --
# │    │    └─Conv2d: 3-121                [1, 1024, 2, 2]           1,048,576
# │    │    └─BatchNorm2d: 3-122           [1, 1024, 2, 2]           2,048
# │    │    └─ReLU: 3-123                  [1, 1024, 2, 2]           --
# │    │    └─Conv2d: 3-124                [1, 1024, 1, 1]           9,437,184
# │    │    └─BatchNorm2d: 3-125           [1, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-126                  [1, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-127                [1, 2048, 1, 1]           2,097,152
# │    │    └─BatchNorm2d: 3-128           [1, 2048, 1, 1]           4,096
# │    │    └─Sequential: 3-129            [1, 2048, 1, 1]           2,101,248
# │    │    └─ReLU: 3-130                  [1, 2048, 1, 1]           --
# │    └─Bottleneck: 2-15                  [1, 2048, 1, 1]           --
# │    │    └─Conv2d: 3-131                [1, 1024, 1, 1]           2,097,152
# │    │    └─BatchNorm2d: 3-132           [1, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-133                  [1, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-134                [1, 1024, 1, 1]           9,437,184
# │    │    └─BatchNorm2d: 3-135           [1, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-136                  [1, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-137                [1, 2048, 1, 1]           2,097,152
# │    │    └─BatchNorm2d: 3-138           [1, 2048, 1, 1]           4,096
# │    │    └─ReLU: 3-139                  [1, 2048, 1, 1]           --
# │    └─Bottleneck: 2-16                  [1, 2048, 1, 1]           --
# │    │    └─Conv2d: 3-140                [1, 1024, 1, 1]           2,097,152
# │    │    └─BatchNorm2d: 3-141           [1, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-142                  [1, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-143                [1, 1024, 1, 1]           9,437,184
# │    │    └─BatchNorm2d: 3-144           [1, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-145                  [1, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-146                [1, 2048, 1, 1]           2,097,152
# │    │    └─BatchNorm2d: 3-147           [1, 2048, 1, 1]           4,096
# │    │    └─ReLU: 3-148                  [1, 2048, 1, 1]           --
# ├─AdaptiveAvgPool2d: 1-9                 [1, 2048, 1, 1]           --
# ├─Linear: 1-10                           [1, 10]                   20,490
# ==========================================================================================
# Total params: 66,854,730
# Trainable params: 66,854,730
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 232.66
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.70
# Params size (MB): 267.42
# Estimated Total Size (MB): 272.13
# ==========================================================================================
# Epoch 1/10, Loss: 1.1528, Validation Accuracy: 66.05%
# Epoch 2/10, Loss: 0.8735, Validation Accuracy: 69.34%
# Epoch 3/10, Loss: 0.7410, Validation Accuracy: 71.32%
# Epoch 4/10, Loss: 0.6375, Validation Accuracy: 72.27%
# Epoch 5/10, Loss: 0.5384, Validation Accuracy: 72.42%
# Epoch 6/10, Loss: 0.4539, Validation Accuracy: 71.87%
# Epoch 7/10, Loss: 0.3793, Validation Accuracy: 72.34%
# Epoch 8/10, Loss: 0.3255, Validation Accuracy: 72.50%
# Epoch 9/10, Loss: 0.2529, Validation Accuracy: 67.54%
# Epoch 10/10, Loss: 0.2199, Validation Accuracy: 71.99%
